# %% [markdown]
# ##### 01: Get most recent file

# %%
from src.bronze.get_most_recent_file import get_recent_file

raw_data = get_recent_file("category")
# raw_data.show()

# %% [markdown]
# ##### 02: Store data in bronze layer delta lake table

# %%
from src.bronze.store_bronze_data import save_data
# print(type(raw_data))
save_data(raw_data, data_type="category")

# %% [markdown]
# ##### 03: test to see if table is saved

# %%
test_df = spark.table('coin_gecko_dev.bronze.category')
# test_df = spark.sql("SELECT * FROM coin_gecko_dev.bronze.category")
test_df.show()
