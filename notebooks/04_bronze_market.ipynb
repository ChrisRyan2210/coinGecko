# %% [markdown]
# ##### 01: Retrieve raw data from Volume

# %%
from src.bronze.get_most_recent_file import get_recent_file

raw_df = get_recent_file("market")

# %% [markdown]
# ##### 02: Save the data into a delta table

# %%
from src.bronze.store_bronze_data import save_data

save_data(raw_df, data_type="market")

# %% [markdown]
# ##### 03: test the table

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

test_df = spark.table('coin_gecko_dev.bronze.market')
test_df.show()
