# %% [markdown]
# ##### 01: Retrieve api_key

# %%
from src.utils.get_api_info import get_api_info

key, scope, base_url = get_api_info()

api_key = dbutils.secrets.get(scope=scope, key=key)

# %% [markdown]
# ##### 02: Call the price api function

# %%
from src.api.category_data import get_category_data

data = get_category_data(api_key, base_url)

# %% [markdown]
# ##### 03: Save the data in volume

# %%
from src.raw.raw_storage import save_raw_json

save_raw_json(
    data=data,
    file_type="category",
)
